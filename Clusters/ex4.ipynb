# %%
# Importando as bibliotecas necessárias
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#Definindo os dados

dia_semana = [1,2,3,4,5,6,7]
n_de_clientes= [15,20,30,100,350,500,700]

# %%
# Criando um DataFrame 
df = pd.DataFrame({
    'Dias': dia_semana,
    'Clientes': n_de_clientes
})

# %%
# Exibindo o DataFrame
print("DataFrame")
print(df)
# Out:
# DataFrame
#    Dias  Clientes
# 0     1        15
# 1     2        20
# 2     3        30
# 3     4       100
# 4     5       350
# 5     6       500
# 6     7       700

# %%
# Aplicando o algoritmo KMeans
kmeans = KMeans(n_clusters=3, random_state=0)
df['Cluster'] = kmeans.fit_predict(df[['Clientes']])

# %%
# Exibindo o DataFrame com os clusters
print("\nDataFrame com Clusters:")
print(df)
# Out:
# DataFrame com Clusters:
#    Dias  Clientes  Cluster
# 0     1        15        0
# 1     2        20        0
# 2     3        30        0
# 3     4       100        0
# 4     5       350        2
# 5     6       500        2
# 6     7       700        1

# %%
# Plotando os resultados
plt.scatter(df['Dias'], df['Clientes'], c=df['Cluster'], cmap='viridis', marker='o')
plt.scatter(kmeans.cluster_centers_, kmeans.predict(kmeans.cluster_centers_.reshape(-1, 1)), marker='x', color='red', s=100, label='Centroides')
plt.xlabel('Dias')
plt.ylabel('Clientes')
plt.title('Agrupamento Usando KMeans')
plt.legend()
plt.show()
# Out:
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
